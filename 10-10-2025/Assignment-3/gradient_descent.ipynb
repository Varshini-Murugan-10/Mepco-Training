# %%
import pandas as pd
import numpy as np
import pandas as pd
import io
from google.colab import files
import matplotlib.pyplot as plt

def f(w,b,x):
  return 1.0/(1.0+np.exp(-(w*x+b)))

# calculate loss/error

def error(w,b):
  err=0.0
  for x,y in zip(X,Y):
    fx=f(w,b,x)
    err+=0.5*(fx-y)**2
  return err

def grad_b(w,b,x,y):
  fx=f(w,b,x)
  return (fx-y)*fx*(1-fx)

def grad_w(w,b,x,y):
  fx=f(w,b,x)
  return (fx-y)*fx*(1-fx)*x
def do_gradient_descent(X,Y,w,b,eta,max_epochs):
  dw=0
  db=0
  Loss=[]
  for i in range(max_epochs):
    for x,y in X,Y:
      dw+=grad_w(w,b,x,y)
      db+=grad_b(w,b,x,y)
    w=w-eta*dw
    b=b-eta*db
    print('Epoch ',i)
    print('Loss = ',error(w,b))
    Loss.append(error(w,b))
  return w,b,Loss
def sigmoid(x):
  return 1/(1+np.exp(-x))

import numpy as np

x = np.linspace(-10, 10, 1000) # 1000 points between -10 and 10

# Calculate the corresponding y-values using the sigmoid function

weights = np.linspace(-1, 1, 1000) # 1000 points between -10 and 10
bias = 0.01
temp = np.dot(weights, x) + bias

Y = sigmoid(temp)
plt.scatter(temp,Y,marker='*')
plt.xlabel("x")
plt.ylabel("y")

initial_w=1
initial_b=1
eta=0.01
max_epochs=100

w,b,l=do_gradient_descent(temp,Y,initial_w,initial_b,eta,max_epochs)

plt.plot(l)
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2955006513.py in <cell line: 0>()
#      62 max_epochs=100
#      63
# ---> 64 w,b,l=do_gradient_descent(temp,Y,initial_w,initial_b,eta,max_epochs)
#      65
#      66 plt.plot(l)
#
# /tmp/ipython-input-2955006513.py in do_gradient_descent(X, Y, w, b, eta, max_epochs)
#      30   Loss=[]
#      31   for i in range(max_epochs):
# ---> 32     for x,y in X,Y:
#      33       dw+=grad_w(w,b,x,y)
#      34       db+=grad_b(w,b,x,y)
#
# TypeError: cannot unpack non-iterable numpy.float64 object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-254140961.py in <cell line: 0>()
#      22 max_epochs=100
#      23
# ---> 24 w,b,l=do_gradient_descent(temp,y,initial_w,initial_b,eta,max_epochs)
#      25
#      26 plt.plot(l)
#
# /tmp/ipython-input-2376142300.py in do_gradient_descent(X, Y, w, b, eta, max_epochs)
#      30   Loss=[]
#      31   for i in range(max_epochs):
# ---> 32     for x,y in zip(X,Y):
#      33       dw+=grad_w(w,b,x,y)
#      34       db+=grad_b(w,b,x,y)
#
# TypeError: 'numpy.float64' object is not iterable
