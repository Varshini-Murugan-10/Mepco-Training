# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

original = cv2.imread("/content/003.png", cv2.IMREAD_GRAYSCALE)

laplacian = cv2.Laplacian(original, cv2.CV_64F)
laplacian_8bit = cv2.convertScaleAbs(laplacian)
sharpened = cv2.addWeighted(original, 1.5, laplacian_8bit, 0.5, 0)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(original, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(laplacian_8bit, cmap='gray')
plt.title('Laplacian (Absolute)')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(sharpened, cmap='gray')
plt.title('Enhanced/Sharpened Surface')
plt.axis('off')
plt.show()
